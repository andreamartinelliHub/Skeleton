# %%
import joblib
import torch
from src import utils
weights = joblib.load('../weights_tmp.joblib')

# weights = torch.stack(weights).squeeze(1).numpy()
utils.plot_weights_heatmap(weights, figsize = (12,6))
